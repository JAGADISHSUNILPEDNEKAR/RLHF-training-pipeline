# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Add project root to path if running from notebooks dir
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.annotation import AnnotationUI

ui = AnnotationUI()
ui.display()
